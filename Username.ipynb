# %%
#validate user input exercise
#1. username is no more than 12 characters
#2. username must not contain spaces
# 3. username must not contain digits
def UserName():
    return input("Please enter you're user name...👤:\n")
Uname = UserName()
space = Uname.find(" ")
if len(Uname) >12 or len(Uname) < 6 or space != -1 or not Uname.isalpha():
    print("Please enter the user name properly..🫡")
    Uname = UserName()
else:
    print("Wellcome 👏")
# Out:
# Please enter you're user name...👤:
#  hhhhhhshsh
# -1
# Wellcome 👏
