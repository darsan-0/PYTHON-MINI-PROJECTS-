# %%
#indexing = accessing elements of a sequence using [] (indexing operator)
#[start end: step]

CCNum = "1234-5678-9012-3456"
last_digits = CCNum[-4:]
print(f"XXXX-XXXX-XXXX-{last_digits}")
# Out:
# XXXX-XXXX-XXXX-3456

# %%
revers_CCNum = CCNum[::-1]
print("Reversed CCNum is : ",revers_CCNum)
# Out:
# Reversed CCNum is :  6543-2109-8765-4321
