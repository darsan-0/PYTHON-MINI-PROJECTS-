# %%
#This is my first Python program.
print("I am Darsan")
# Out:
# I am Darsan

# %%
print("Let's rock to gether!")
# Out:
# Let's rock to gether!

# %%
# Variable =
# A container for a value (string, integer, float, boolean)
# A variable behaves as if it was the value it contains
Name = "Darsan"
print(Name)
Age = 19
print(Age)
CGPA = 9.27
print(CGPA)
is_py = True
print()
print(f"Hello this is {Name},I am {Age} old With CGPA:{CGPA}.This is python from basics? : {is_py}")
# Out:
# Darsan
# 19
# 9.27
#
# Hello this is Darsan,I am 19 old With CGPA:9.27.This is python from basics? : True

# %%
# Typecasting = the process of converting a variable from one data type to another str(), int(), float(), bool()

Age = float(Age)
print(Age)
print()
CGPA = int(CGPA)
print(CGPA)
# Out:
# 19.0
#
# 9

# %%
# input() = A function that prompts the user to enter data
#I Returns the entered data as a string
Iname = input("Hello Bro, Enter your name: ")

Iage = int(input("How old are you Darling:"))
age = Iage +1
print(f"My name is {Iname}")
print("Happy Birthday Broo..😜")
print("You're age is ",age)
# Out:
# Hello Bro, Enter your name:  Darsan
# How old are you Darling: 18
# My name is Darsan
# Happy Birthday Broo..😜
# You're age is  19

# %%
#if = Do some code only IF some condition is True
#Else do something else
if age >= 18:
    print("You're are eligibale to VOTE...🐾")
elif age < 0:
    print("Are your a alin...👽")
else:
    print("Sorry, you're age must be More than or equal to 18")
# Out:
# You're are eligibale to VOTE...🐾

# %%
# name = input("Enter your full name: ")
# phone_number = input("Enter your phone #: ")
#result = len(name)
# result = name.find("o")
# result = name.rfind("q")
# name = name.capitalize()
# name = name.upper()
# name = name.lower()
# result = name.isdigit()
# result = name.isalpha()
#result = phone_number.count('-")
# phone_number.replace("-"," ")
print(help(str))
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...
